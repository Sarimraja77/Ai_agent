# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")

response = llm.invoke(input("Enter Your Question\n"))
print(response.text)
# Out:
# Enter Your Question
#  How many atomic countries are?
# There are **9 countries** in the world known to possess nuclear weapons.
#
# Here is the list of those nations:
#
# 1. **United States**
# 2. **Russia**
# 3. **United Kingdom**
# 4. **France**
# 5. **China**
# 6. **India**
# 7. **Pakistan**
# 8. **North Korea**
# 9. **Israel** (which has a policy of nuclear ambiguity, neither confirming nor denying its arsenal, but is universally accepted by experts to have one).
#
# Additionally, a few other countries—known as **"nuclear-sharing" nations**—do not own nuclear weapons themselves, but host U.S. nuclear weapons on their soil as part of NATO agreements. These countries are **Belgium, Germany, Italy, the Netherlands, and Turkey**.

# %%
prompt = "write a tagline for my fabric shop?"
system = "Answer should be precise"
llm = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite",temperature=0)

response = llm.invoke(prompt)
print(response.text)

# %%
prompt = "write a tagline for my fabric shop?"
llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it",temperature=1)

response = llm.invoke(prompt)
print(response.text)
# Out:
# Since I don’t know the specific "vibe" of your shop (luxury, cozy, modern, or budget-friendly), I have broken these down by category.
#
# Choose the one that best fits your brand personality:
#
# ### 🌟 Creative & Inspirational
# *Focuses on the act of making and the imagination of the customer.*
# *   **Where every stitch tells a story.**
# *   **Bringing your imagination to life.**
# *   **Fueling your creative spark.**
# *   **Your vision. Our fabric.**
# *   **Dream it. Design it. Sew it.**
# *   **The starting point for every masterpiece.**
#
# ### ✨ Elegant & High-End
# *Focuses on quality, luxury, and sophistication.*
# *   **Exquisite textiles for the discerning creator.**
# *   **Quality you can feel, beauty you can see.**
# *   **The art of fine fabric.**
# *   **Timeless textiles. Endless elegance.**
# *   **Curated fabrics for exceptional designs.**
# *   **Where luxury meets the needle.**
#
# ### 🧶 Cozy & Homey
# ...

# %%
response = llm.invoke([
    ["system","Answer should be precise"],
    ["human","How many moons does jupyter have"]
])
print(response.text)
# Out:
# Jupiter has **95** officially recognized moons.
